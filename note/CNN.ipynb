# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests

def load_data():
    url = 'http://43.202.66.118:8016/all'
    r = requests.get(url).json()
    return r

data = load_data()
df = pd.DataFrame(data)
df
# Out:
#      num    file_name label  \
# 0      1  7_25452.png
# 1      2  7_25452.png
# 2      3  7_25452.png
# 3      4  7_25452.png
# 4      5  7_25452.png
# ..   ...          ...   ...
# 299  303       1.jpeg     1
# 300  304       1.jpeg     1
# 301  305       1.jpeg     1
# 302  306       1.jpeg     1
# 303  307       1.jpeg     1
#
#                                              file_path         request_time  \
# 0    /home/ubuntu/images/n11/0bacd2a5-d393-4152-a50...  2024-09-25 10:30:38
# 1    /home/ubuntu/images/n11/4410feba-fde6-4107-81c...  2024-09-25 10:30:39
# 2    /home/ubuntu/images/n11/e238684e-3caa-4417-aba...  2024-09-25 10:30:39
# 3    /home/ubuntu/images/n11/db967479-5ffc-492b-b92...  2024-09-25 10:30:39
# 4    /home/ubuntu/images/n11/59fc767d-3834-4b31-857...  2024-09-25 10:30:39
# ..                                                 ...                  ...
# 299  /home/ubuntu/images/n23/635c0ffe-838b-4d77-927...  2024-09-25 16:56:41
# ...

# %%
df['request_time'] = pd.to_datetime(df['request_time'])
df['request_time'] = df['request_time'].dt.strftime('%Y-%m-%d %H')

df['prediction_time'] = pd.to_datetime(df['prediction_time'])
df['prediction_time'] = df['prediction_time'].dt.strftime('%Y-%m-%d %H')

r_time = df.groupby('request_time').size()
p_time = df.groupby('prediction_time').size()

plt.title('Requests by Date and Time')
plt.bar(r_time.index, r_time.values)
plt.plot(p_time.index, p_time.values, marker='o', color='r')
plt.xlabel('Date and Time')  # x축 레이블
plt.ylabel('Count')  # y축 레이블
plt.xticks(rotation = 45)
plt.show()

# %%
user = df.groupby('request_user').size()

plt.title('Requests by User')
plt.bar(user.index, user.values)
plt.plot(user.index, user.values, marker='o', color='r')
plt.xlabel('Request User')  # x축 레이블
plt.ylabel('Count')  # y축 레이블
plt.xticks(rotation = 45)
plt.show()

# %%
req_cnt = df.groupby('request_user').size().reset_index(name='req_cnt')
req_cnt.set_index('request_user', inplace=True)
req_cnt.rename_axis('user', inplace=True)
prd_cnt = df.groupby('prediction_model').size().reset_index(name='prd_cnt')
prd_cnt.set_index('prediction_model', inplace=True)
prd_cnt.rename_axis('user', inplace=True)

join_df = req_cnt.join(prd_cnt, how='left')
join_df
# Out:
#       req_cnt  prd_cnt
# user
# n01         7      4.0
# n03         4      NaN
# n04         6     40.0
# n05         9      NaN
# n06         9      1.0
# n07         7      3.0
# n08         6      NaN
# n11         9      NaN
# n13         5     11.0
# n16        12      NaN
# n18         3      NaN
# n21        11      8.0
# n22         1      1.0
# n23        11      6.0
# n77       204     30.0

# %%
#index = np.arange(2)
#bar_width = 0.5

#plt.title('Requests by User')
#plt.bar(index, user.index, user.values, color='b')
#plt.bar(index+bar_width, model.index, model.values, color='r')
#plt.xlabel('prediction_model')  # x축 레이블
#plt.ylabel('Count')  # y축 레이블
#plt.xticks(rotation = 90)
#plt.show()

# %%
#plt.title('Requests by User')
#plt.bar(user.index, user.values)
#plt.plot(user.index, user.values, marker='o', color='r')
#plt.xlabel('Request User')  # x축 레이블
#plt.ylabel('Count')  # y축 레이블
#plt.xticks(rotation = 45)
#plt.show()

index = np.arange(len(merge_df.index))
bar_width = 0.4
b1 = plt.bar(index, merge_df['req_cnt'], bar_width, alpha=0.4, color='red', label='req')
b2 = plt.bar(index + bar_width, merge_df['prd_cnt'], bar_width, alpha=0.4, color='blue', label='prd')

plt.xlabel('User')
plt.ylabel('Counts')
plt.title('Request Count and Product Count by User')
plt.xticks(index, merge_df.index)
plt.legend()
plt.show()

# %%
# Out:
# 15
